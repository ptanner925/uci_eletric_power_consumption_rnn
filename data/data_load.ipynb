# %%
from ucimlrepo import fetch_ucirepo 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns

# %%
  
# fetch dataset 
individual_household_electric_power_consumption = fetch_ucirepo(id=235) 
  
# data (as pandas dataframes) 
df = individual_household_electric_power_consumption.data.features




df.to_csv('household_power_consumption.csv', index=False)
# Out:
# /Users/Ptanner/opt/miniconda3/envs/uci_pwr_rnn/lib/python3.9/site-packages/ucimlrepo/fetch.py:97: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_url)
